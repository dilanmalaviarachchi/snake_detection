# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.8/644.8 kB 8.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8m.pt")
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 156MB/s]

# %%
# !cat /proc/cpuinfo
# !cat /proc/meminfo

# %%
model.train(data="/content/drive/MyDrive/Project NSBM/data.yaml", epochs=100)
# Out:
# Ultralytics YOLOv8.0.204 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
